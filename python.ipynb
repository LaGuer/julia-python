# %% [markdown]
# This is a basic Python notebook dedicated to pandas, matplotlib plotting and numpy calculation examples.
# Try it on MyBinder:
# [![Binder](http://mybinder.org/badge.svg)](http://beta.mybinder.org/v2/gh/laguer/julia-python/master)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
df = pd.DataFrame({
    'name':['Bohr Atom Diameter', 'Mean Pion', 'Rydberg reduced wavelength/pi', 'Half Mean Weak Boson', 'Higgs Boson', 'Cosmic Photon hc/2kT T=2.73K', 'X Boson GUT', 'White Dwarf Diameter', 'Kotov cycle - Stellar System', 'Milankovitch cycle - Galaxy', 'Hubble Radius x 2pi', 'HOL', 'Large periodicity', 'Grand cosmos diameter * H'],
    'y_value':[1.72515, 1.72155, 2.426, 2.428, 2.51872, 3.12, 3.78446, 3.755, 4.078, 4.363, 4.506, 5.253, 5.199, 5.4321],
    'pow':['10**3','10**3','10**5','10**5','10**6','10**11','10**20','10**20','10**22','10**30','10**38','10**80','10**80','10**80'],
    'state':['x','+','x','+','o','x','+','x','x','x','x','+','o','o'],
    'num_p':[10,10,14,14,14,18,22,22,24,25,26,30,30,30],
    'num_n':[0, 1, 2, 3, 4, 5, 5, 6, 6, 6, 7, 7, 7, 7]
})
df[['name','y_value','pow','state','num_p','num_n']]
#df[['name','y_value','pow','state']]
# Out:
#                              name  y_value     pow state  num_p  num_n
# 0              Bohr Atom Diameter  1.72515   10**3     x     10      0
# 1                       Mean Pion  1.72155   10**3     +     10      1
# 2   Rydberg reduced wavelength/pi  2.42600   10**5     x     14      2
# 3            Half Mean Weak Boson  2.42800   10**5     +     14      3
# 4                     Higgs Boson  2.51872   10**6     o     14      4
# 5    Cosmic Photon hc/2kT T=2.73K  3.12000  10**11     x     18      5
# 6                     X Boson GUT  3.78446  10**20     +     22      5
# 7            White Dwarf Diameter  3.75500  10**20     x     22      6
# 8    Kotov cycle - Stellar System  4.07800  10**22     x     24      6
# 9     Milankovitch cycle - Galaxy  4.36300  10**30     x     25      6
# 10            Hubble Radius x 2pi  4.50600  10**38     x     26      7
# 11                            HOL  5.25300  10**80     +     30      7
# ...

# %%
# plot num_p vs y_value
df.plot(kind='scatter',x='num_p',y='y_value',color='red')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 5
h = 5
d = 140
plt.figure(figsize=(w, h), dpi=d)

#plt.figure()
x = [10, 14, 18, 22, 24, 25, 26]
y = [1.72515*10**3, 2.426*10**10, 3.12*10**11, 3.755*10**20, 4.159*10**30, 4.342*10**33, 4.506*10**45]
plt.scatter(x, y)

x2 = [10, 14, 22, 30]
y2 = [1.72155*10**3, 2.428*10**10, 3.78446*10**20, 5.253*10**80]
plt.scatter(x2, y2)

x3 = [14, 30]
y3 = [2.51872*10**10, 5.199*10**80]
plt.scatter(x3, y3)

plt.plot(x, y)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.yscale('log')
#plt.loglog(y, y2, y3)
plt.show()

# %%
# needed to display the graphs
# %matplotlib inline
from pylab import *

# %%
w = 10
h = 10
d = 120

x = array([2, 6, 10, 14, 18, 22, 26, 30])
x4 = array([2, 6, 10, 14, 18, 22, 26, 30])
x5 = array([0, 1, 2, 3, 4, 5, 6, 7])
x1 = array([10, 14, 18, 26])
y1 = array([1.72515*10**3, 2.35457*10**5, 3.15010*10**14, 4.48545*10**40])
#plt.scatter(x, y)

x2 = array([10, 14, 22, 30])
y2 = array([1.72155*10**3, 2.48733*10**5, 3.78446*10**22, 5.2542*10**82])
#plt.scatter(x2, y2)

x3 = array([14, 30])
y3 = array([2.51872*10**5, 4.8185*10**40])
y4 = array([0, 1, 2, 3, 4, 5, 6])
y = exp((2)**(x / 4))
#y4 = exp(exp((2))**(x / 4))
#y1 = (exp(2)**(x / 4))

#fig, ax = plt.subplots()
#fig1, ax = plt.figure()
# left, bottom, width, height (range 0 to 1)
#axes = fig.add_axes([0, 1e160, 5])

#ax.plot(x, y1+1, color="red", linewidth=0.25)
#ax.plot(x, y1+2, color="blue", linewidth=0.50)
#ax.plot(x, y1+3, color="blue", linewidth=1.00)
#ax.plot(x, y1+4, color="blue", linewidth=2.00)

# marker size and color
#ax.plot(x1, y1, color="red", lw=1, ls='-', marker='x', markersize=8, 
#        markerfacecolor="yellow", markeredgewidth=2, markeredgecolor="red")
#ax.plot(x2, y2, color="green", lw=1, ls='-', marker='o')
#ax.plot(x3, y3, color="black", lw=1, ls='-', marker='+',  markerfacecolor="black")
#ax.plot(x, y, color="purple", lw=1, ls='-', marker='*', markersize=8,   markerfacecolor="red")
#ax.scatter(x1, y1, color="red", marker='x')
#ax.scatter(x2, y2, color="green", marker='o')
#ax.scatter(x3, y3, color="black", marker='+')
#axes.plot(x, y, 'r')

#ax.plot(x, y, 'm')
#ax.plot(x4, y4, 'y')
# symmetric log
plt.subplot(223)
plt.figure(figsize=(w, h), dpi=d)
#plt.plot(x, y - y.mean())
plt.plot(x, y )
plt.yscale('symlog', linthreshy=0.01)
plt.title('symlog')
plt.grid(True)
plt.xlabel('log2**x with x=p/4 and 0<p<7 or 2<P<30' )
plt.ylabel('0<n<6 and n=4p+2')
plt.title('Micro/Macro Physics DA')
plt.scatter(x1, y1, color="red", marker='x')
plt.scatter(x2, y2, color="green", marker='o')
plt.scatter(x3, y3, color="black", marker='+')
plt.plot(x1, y1, 'r')
plt.plot(x2, y2, 'g')
plt.plot(x3, y3, 'b')
plt.plot(x, exp(2)**(x/4), color="black", label=r"+ sign represents micro-physics correlation with $y = lnln(\frac{\lambdabar_e(n)}{\lambdabar_mi})$")
plt.plot(x, x**3, color="red", label=r"x sign represents macro-physics correlation with $y = lnln(\frac{\lambdabar_ma(n)}{\lambdabar_e})$")
plt.legend(loc=2) # upper left corner
#plt.text(10, 1.72515, r'$\mu=100,\ \sigma=15$ Bohr Diameter')
plt.text(10, 1.72155*10**3, r'Π Mean Pion')
plt.text(14, 2.35*10**5, r'Rydberg')
#plt.text(14, 2.48*10**5, r'Mean Intermediary Boson')
plt.text(14, 2.51*10**10, r'Higgs Boson')
plt.text(22, 3.78*10**22, r'X Boson GUT')
plt.text(26, 4.48*10**40, r'Hubble Radius')
plt.text(28, 4.81*10**80, r'Large Periodicity')
plt.text(32, 5.25*10**82, r'HOL')
#plt.figure(figsize=(w, h), dpi=d)
ax2 = plt.twinx()
ax2.plot(x, exp(2)**x, lw=1, color="m")
ax2.set_ylabel(r"lnln $(2^n/^4)$", fontsize=18, color="red")
for label in ax2.get_yticklabels():
    label.set_color("red")
ax3 = plt.twiny()
#ax3.plot(x5, exp(2)**x5, lw=1, color="m")
ax3.set_xlabel(r"lnln $(2^n/^4)$", fontsize=18, color="red")
for label in ax2.get_xticklabels():
    label.set_color("yellow")

# %%
import matplotlib.pyplot as plt
w = 4
h = 3
d = 120
plt.figure(figsize=(w, h), dpi=d)
x = [2, 6, 10, 14, 18, 22, 26, 30]
x1 = array([2, 6, 10, 14, 18, 22, 26, 30])
y = [1.72515*10**3, 1.72155*10**3, 2.35457*10**5, 2.48733*10**5,  3.15010*10**14, 3.78446*10**22, 4.48545*10**40, 5.2542*10**82]
#f(y1) = log((2)**w
plt.loglog(x, y)
#plt.plot(x1, y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
from pylab import *

# %%
# scaling
fig, axes = plt.subplots(1, 2, figsize=(10,4))
      
axes[0].plot(x, log(2)**(x/4), x, log(x))
axes[0].set_title("Normal scale")

axes[1].plot(x, log(2)**(x/4), x, log(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)");
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-2f54e65d7b08> in <module>
#       2 fig, axes = plt.subplots(1, 2, figsize=(10,4))
#       3
# ----> 4 axes[0].plot(x, log(2)**(x/4), x, log(x))
#       5 axes[0].set_title("Normal scale")
#       6
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# axis controls
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-d6576f3eb4fe> in <module>
#       3 fig, axes = plt.subplots(1, 3, figsize=(12, 4))
#       4
# ----> 5 axes[0].plot(x, x**2, x, x**3)
#       6 axes[0].set_title("default axes ranges")
#       7
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'

# %%
# other plot styles
xx = np.linspace(-0.75, 1., 100)
n = array([0,1,2,3,4,5,6,7])
n1 = array([2,6,10,14,18,22,26,30])

fig, axes = plt.subplots(1, 4, figsize=(12,3))

axes[0].scatter(xx, xx + 0.25*randn(len(xx)))
axes[0].set_title("scatter")

axes[1].step(n, exp(2)**(n/4), lw=2)
axes[1].set_title("step")

axes[2].bar(n, exp(2)**(n/4), align="center", width=0.5, alpha=0.5)
axes[2].set_title("bar")

#axes[3].fill_between(x, x**2, x**3, color="green", alpha=0.5);
#axes[3].set_title("fill_between");
# Out:
# Text(0.5, 1.0, 'bar')

# %%
# other plot styles
xx = np.linspace(2, 30., 100)
n = array([0,1,2,3,4,5,6,7])
n1 = array([2,6,10,14,18,22,26,30])

fig, axes = plt.subplots(1, 4, figsize=(12,3))

axes[0].scatter(xx, xx + 0.25*randn(len(xx)))
axes[0].set_title("scatter")

axes[1].step(n, exp(2)**(n/4), lw=2)
axes[1].set_title("step")

axes[2].bar(n, exp(2)**(n/4), align="center", width=0.5, alpha=0.5)
axes[2].set_title("bar")

#axes[3].fill_between(x, x**2, x**3, color="green", alpha=0.5);
#axes[3].set_title("fill_between");
# Out:
# Text(0.5, 1.0, 'bar')

# %%
xx
# Out:
# array([ 2.        ,  2.28282828,  2.56565657,  2.84848485,  3.13131313,
#         3.41414141,  3.6969697 ,  3.97979798,  4.26262626,  4.54545455,
#         4.82828283,  5.11111111,  5.39393939,  5.67676768,  5.95959596,
#         6.24242424,  6.52525253,  6.80808081,  7.09090909,  7.37373737,
#         7.65656566,  7.93939394,  8.22222222,  8.50505051,  8.78787879,
#         9.07070707,  9.35353535,  9.63636364,  9.91919192, 10.2020202 ,
#        10.48484848, 10.76767677, 11.05050505, 11.33333333, 11.61616162,
#        11.8989899 , 12.18181818, 12.46464646, 12.74747475, 13.03030303,
#        13.31313131, 13.5959596 , 13.87878788, 14.16161616, 14.44444444,
#        14.72727273, 15.01010101, 15.29292929, 15.57575758, 15.85858586,
#        16.14141414, 16.42424242, 16.70707071, 16.98989899, 17.27272727,
#        17.55555556, 17.83838384, 18.12121212, 18.4040404 , 18.68686869,
#        18.96969697, 19.25252525, 19.53535354, 19.81818182, 20.1010101 ,
# ...

# %%
# annotations
fig, ax = plt.subplots()

ax.plot(xx, exp(2)**(xx/4), xx, exp(2)**xx/4)

ax.text(1.15, 10^20, r"$y=exp(2)^(xx/4)$", fontsize=20, color="blue")
ax.text(16.65, 2e10, r"$y=exp(2)^xx/4$", fontsize=20, color="green");

# %%
# annotations
fig, ax = plt.subplots()

ax.plot(xx, xx**2, xx, xx**3)

ax.text(0.15, 0.2, r"$y=x^2$", fontsize=20, color="blue")
ax.text(0.65, 0.1, r"$y=x^3$", fontsize=20, color="green");

# %%
# color map
alpha = 0.7
phi_ext = 2 * pi * 0.5

def flux_qubit_potential(phi_m, phi_p):
    return ( + alpha - 2 * cos(phi_p)*cos(phi_m) - 
        alpha * cos(phi_ext - 2*phi_p))

phi_m = linspace(0, 2.718*pi, 100)
phi_p = linspace(0, 2.718*pi, 100)
X,Y = meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X, Y).T

fig, ax = plt.subplots()

p = ax.pcolor(X/(2*pi), Y/(2*pi), Z, 
              cmap=cm.RdBu, vmin=abs(Z).min(), vmax=abs(Z).max())
cb = fig.colorbar(p, ax=ax)

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
# surface plots
fig = plt.figure(figsize=(14,6))

# `ax` is a 3D-aware axis instance because of the projection='3d' 
# keyword argument to add_subplot
ax = fig.add_subplot(1, 2, 1, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# surface_plot with color grading and color bar
ax = fig.add_subplot(1, 2, 2, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, 
                    cmap=cm.coolwarm, linewidth=0, antialiased=False)
cb = fig.colorbar(p, shrink=0.5)

# %%
# wire frame
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(1, 1, 1, projection='3d')

p = ax.plot_wireframe(X, Y, Z, rstride=4, cstride=4)

# %%
# contour plot with projections
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(1,1,1, projection='3d')

ax.plot_surface(X, Y, Z, rstride=4, cstride=4, alpha=0.25)
cset = ax.contour(X, Y, Z, zdir='z', offset=-pi, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-pi, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=3*pi, cmap=cm.coolwarm)

ax.set_xlim3d(-pi, 2.718*pi);
ax.set_ylim3d(0, 3.141*pi);
ax.set_zlim3d(-pi, 2.718*pi);

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

# %%
x = 271 * np.random.rand(841)
y = 314 * np.random.rand(841)
areas = 1000 * np.random.rand(841)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(x, y, s=areas, c=areas, alpha=.5)

# %%
(27182*31415)**8412

# %%
3141592653589793*2718281828459045
# Out:
# 8539734222673565677848730527685

# %%
8539734222673565677848730527685**84128
